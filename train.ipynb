# %%
# standard packages
from os import listdir
from tqdm import tqdm
import os
import pickle
import dill as dill_pickle

# data science stack packages
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import ExtraTreesRegressor

# our implementation
from dataloader import DataLoader, FeatureLoader
from features import *
from selection import GridSearchWeightedCV
from selection import SelectKBestIC, SelectKBestWeightedR2
from pipeline import Winsorizer
from EDA import EDA
from get_IC import *
import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time

# first read the data from raw dataset
if os.path.isfile('data/data.p') == True:
    data = pickle.load(open('data/data.p', 'rb'))
else:
    dataloader = DataLoader('data')
    data = dataloader.load_features(start_date='20140102', end_date='20171229', how='outer')
    pickle.dump(data, open('data/data.p', 'wb'))
# Out:
# Wall time: 732 ms

# %%
#Maybe better to put these three features to dataloader.py

#Retrieve price from return.
#Benchmark: the price of all stocks on 20140102 being 100
price_from_return = (data['RawNoWinsorCumReturn_close']+1).cumprod()
price_from_return = 100*price_from_return/price_from_return.iloc[0,:]
data['PriceFromReturn_close'] = price_from_return

#factor 6
#Intra-day return
intraday_return = (data['CleanMid_close']-data['CleanMid_open'])/data['CleanMid_open']
data['IntradayReturn'] = intraday_return

#factor 5
#volatility weighted return
vol_weighted_return = data['ResidualNoWinsorCumReturn_close']/data['estVol']
vol_weighted_return.dropna(axis=1,how='all').shape
data['VolWeightedReturn'] = vol_weighted_return

# %%
list(data)
# Out:
# ['MDV_63',
#  'CleanMid_open',
#  'CleanMid_close',
#  'CumVolume_open',
#  'CumVolume_close',
#  'IsOpen_open',
#  'IsOpen_close',
#  'ResidualNoWinsorCumReturn_open',
#  'ResidualNoWinsorCumReturn_close',
#  'RawNoWinsorCumReturn_open',
#  'RawNoWinsorCumReturn_close',
#  'estVol',
#  'SharesOutstanding',
#  'PriceFromReturn_close',
#  'IntradayReturn',
#  'VolWeightedReturn']

# %% [markdown]
# # feature engineering

# %%
feature_loader = FeatureLoader(raw_dir='data', # the raw dataset 
                               feature_dir='features', # where to save the features
                               target_dir='data/return', # your target directory
                               data=data)

# %%
# first you register your feature extractor into the featureloader
# remember to pass the keyword arguments of your extractor

# Jordan's features
feature_loader.register(X_weighted_Y, 
                        name='ts_sum(res_ret*vol,20)/ts_sum(vol,20)',
                        X_name='CumVolume_close', 
                        Y_name='ResidualNoWinsorCumReturn_close', N=20)
feature_loader.register(corr_X_Y, 
                        name='corr(vol,raw_ret,20)',
                        X_name='CumVolume_close', 
                        Y_name='RawNoWinsorCumReturn_close', N=20)
feature_loader.register(ts_kurt_X, 
                        name='ts_kurt(raw_ret,20)', 
                        X_name='RawNoWinsorCumReturn_close', N=20)
feature_loader.register(ts_sum_X, 
                        name='ts_sum(res_ret,5)', 
                        X_name='ResidualNoWinsorCumReturn_close', N=20)
feature_loader.register(MQ, 
                        name='MQ(res_ret,10,0.75,0.25)', 
                        X_name='ResidualNoWinsorCumReturn_close', 
                        N=10, X_rank=False, first_quantile=0.75, second_quantile=0.25)
feature_loader.register(MQ, 
                        name='MQ(res_ret,20,0.75,0.25)', 
                        X_name='ResidualNoWinsorCumReturn_close', 
                        N=20, X_rank=False, first_quantile=0.75, second_quantile=0.25)
feature_loader.register(ts_sum_X_Y, 
                        name='ts_sum(res_ret_day,20)', 
                        X_name='ResidualNoWinsorCumReturn_close',
                        Y_name='ResidualNoWinsorCumReturn_open', 
                        N=20, __and__=np.subtract)
feature_loader.register(ts_sum_X, 
                        name='ts_sum(raw_ret,5)', 
                        X_name='RawNoWinsorCumReturn_close', N=5)
feature_loader.register(MQ, 
                        name='MQ(raw_ret,20,0.75,0.25)',
                        X_name='RawNoWinsorCumReturn_close', 
                        N=20, X_rank=False, first_quantile=0.75, second_quantile=0.25)
feature_loader.register(ts_kurt_X, 
                        name='ts_kurt(rank(estVol),20)', 
                        X_name='estVol', N=20, X_rank=True)
feature_loader.register(ts_kurt_X, 
                        name='rank(ts_kurt(vol,20))',
                        X_name='CumVolume_close', N=20, feature_rank=True)

# Kaylie's features
feature_loader.register(Squared, 
                        name='RawReturn_LogLogSquared', 
                        input_variable='RawNoWinsorCumReturn_close')
feature_loader.register(Reversal, 
                        name='Reversal1D', window=0)
feature_loader.register(Reversal, 
                        name='Reversal5D', window=4)
feature_loader.register(Liquidity, 
                        name='Liquidity_volume_close', 
                        input_variable_name='CumVolume_close', window=5)
feature_loader.register(DataNdaysBefore, 
                        name='IntradayReturn', 
                        input_variable_name='IntradayReturn', window=0)
feature_loader.register(FD, 
                        name='FD1008', 
                        input_variable='PriceFromReturn_close', window=10, d=0.8)
feature_loader.register(BB, 
                        name='BB', input_variable_name='PriceFromReturn_close', 
                        window=20,k=2)
feature_loader.register(DataNdaysBefore, 
                        name='RawNoWinsorCumReturn_close', 
                        input_variable_name='RawNoWinsorCumReturn_close', window=0)

# weight
feature_loader.register(InversedVol, name='1/estVol')

# %%
# %%time
feature_loader.extract(start_date='20140102', end_date='20171228', save=True);
# Out:
# Wall time: 29min 9s

# %%
df_X_y = feature_loader.load_features(start_date='20140102', end_date='20171228')

list(df_X_y.columns)
# Out:
# ['Id',
#  'ts_sum(res_ret*vol,20)/ts_sum(vol,20)',
#  'corr(vol,raw_ret,20)',
#  'ts_kurt(raw_ret,20)',
#  'ts_sum(res_ret,5)',
#  'MQ(res_ret,10,0.75,0.25)',
#  'MQ(res_ret,20,0.75,0.25)',
#  'ts_sum(res_ret_day,20)',
#  'ts_sum(raw_ret,5)',
#  'MQ(raw_ret,20,0.75,0.25)',
#  'ts_kurt(rank(estVol),20)',
#  'rank(ts_kurt(vol,20))',
#  'RawReturn_LogLogSquared',
#  'Reversal1D',
#  'Reversal5D',
#  'Liquidity_volume_close',
#  'IntradayReturn',
#  'FD1008',
#  'BB',
#  'RawNoWinsorCumReturn_close',
#  '1/estVol',
#  'ResidualNoWinsorCumReturn',
#  'Date']

# %% [markdown]
# # ML models

# %%
train_years = {2014, 2015, 2016}
test_years = {2017}

Jordan_flag = True
Kaylie_flag = True

X_y_dropna = False    # if True, dropna in X and y
y_min = -0.05    # min values to clip y 
y_max = 0.05    # max values to clip y

select_by_IC = False
select_by_R2 = False
num_features = 10    # number of features to select

# %%
# get X and y
Jordan_features = [
    'ts_sum(res_ret*vol,20)/ts_sum(vol,20)',   
    'corr(vol,raw_ret,20)',
    'ts_kurt(raw_ret,20)', 
    'ts_sum(res_ret,5)', 
    'MQ(res_ret,10,0.75,0.25)',
    'MQ(res_ret,20,0.75,0.25)',  
    'ts_sum(res_ret_day,20)',      
    'ts_sum(raw_ret,5)',                 
    'MQ(raw_ret,20,0.75,0.25)',               
    'ts_kurt(rank(estVol),20)',            
    'rank(ts_kurt(vol,20))',                   
]
Kaylie_features = [
    'RawReturn_LogLogSquared',
    'Reversal1D',
    'Reversal5D',                   
    'Liquidity_volume_close',       
    'IntradayReturn',                         
    'FD1008',                          
    'BB',                      
    'RawNoWinsorCumReturn_close',      
]

X_y_features = []
if Jordan_flag is True:
    X_y_features += Jordan_features 
if Kaylie_flag is True:
    X_y_features += Kaylie_features 
X_y = df_X_y[X_y_features + ['ResidualNoWinsorCumReturn', '1/estVol', 'Date', 'Id']]


if X_y_dropna == True:
    X_y.dropna(inplace=True)
X_y.index = pd.to_datetime(X_y['Date'])

# %%
# train test split
X_y_train = X_y[X_y.index.year.isin(train_years)]
X_y_test = X_y[X_y.index.year.isin(test_years)]

X_train = X_y_train.iloc[:,:-4]
y_train = X_y_train['ResidualNoWinsorCumReturn']
w_train = X_y_train['1/estVol']

X_test = X_y_test.iloc[:,:-4]
y_test = X_y_test['ResidualNoWinsorCumReturn']
w_test = X_y_test['1/estVol']

# %% [markdown]
# ## XGBoost, with GridSearchWeightedCV

# %%
# %%time

pipe_xgb = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
                           ('winsorizer', Winsorizer(qmin=0.01, qmax=0.99)),
                           ('scaler', StandardScaler()),
#                            ('selector', SelectKBestIC(verbose=False, k=num_features)),
#                            ('R2selector', SelectKBestWeightedR2(verbose=True, k=num_features)),
                           ('xgb', xgb.XGBRegressor(n_jobs=5, random_state=42))
                          ])

# clip y, in pipeline we have to separate the preprocess of X and y
# in case of how to clip, I suggest we do an explortory data analysis
# here I use 0.01 and 0.99 quantile (not the exact number but just the same scale)
# since we used the whole training dataset to get this result
# when we do cross-validation we will peek the future
tt_xgb = TransformedTargetRegressor(regressor=pipe_xgb,
                                    func=lambda y: np.clip(y, a_min=y_min, a_max=y_max),
                                    inverse_func=lambda y: y,
                                    check_inverse=False)

# we have some fit parameters to pass in this model
# you don't need xgb__ prefix for the keyword here
fit_params = {
    "early_stopping_rounds": 5,
    'verbose': 1
}
# some parameters to tune
param_grid = {    
    'xgb__learning_rate': [0.1],
    'xgb__n_estimators': [300],
    'xgb__max_depth': [3],
    'xgb__reg_alpha': [1],
    'xgb__subsample': [0.5],
    'xgb__colsample_bytree': [0.5],
}

search_xgb = GridSearchWeightedCV(estimator=tt_xgb,
                                  param_grid=param_grid,
                                  eval_set=True,
                                  cv=5,
                                  verbose=True,
                                  random_state=42)
search_xgb.fit(X_train, y_train,
               Date=X_y_train['Date'], 
               Id=X_y_train['Id'],
               sample_weight=w_train.fillna(value=0),
               **fit_params)

print('weighted R^2 in train set: ', search_xgb.best_score_)
# Out:
# {'xgb__colsample_bytree': 0.5, 'xgb__learning_rate': 0.1, 'xgb__max_depth': 3, 'xgb__n_estimators': 300, 'xgb__reg_alpha': 1, 'xgb__subsample': 0.5}
# [0]	validation_0-rmse:0.45015
# [1]	validation_0-rmse:0.40517
# [2]	validation_0-rmse:0.36469
# [3]	validation_0-rmse:0.32827
# [4]	validation_0-rmse:0.29548
# [5]	validation_0-rmse:0.26599
# [6]	validation_0-rmse:0.23945
# [7]	validation_0-rmse:0.21557
# [8]	validation_0-rmse:0.19408
# [9]	validation_0-rmse:0.17475
# [10]	validation_0-rmse:0.15736
# [11]	validation_0-rmse:0.14172
# [12]	validation_0-rmse:0.12766
# [13]	validation_0-rmse:0.11501
# [14]	validation_0-rmse:0.10365
# [15]	validation_0-rmse:0.09343
# [16]	validation_0-rmse:0.08425
# [17]	validation_0-rmse:0.07600
# [18]	validation_0-rmse:0.06860
# [19]	validation_0-rmse:0.06197
# [20]	validation_0-rmse:0.05602
# [21]	validation_0-rmse:0.05069
# [22]	validation_0-rmse:0.04592
# [23]	validation_0-rmse:0.04166
# [24]	validation_0-rmse:0.03785
# [25]	validation_0-rmse:0.03447
# [26]	validation_0-rmse:0.03146
# [27]	validation_0-rmse:0.02879
# [28]	validation_0-rmse:0.02643
# [29]	validation_0-rmse:0.02436
# [30]	validation_0-rmse:0.02254
# [31]	validation_0-rmse:0.02095
# [32]	validation_0-rmse:0.01956
# [33]	validation_0-rmse:0.01837
# [34]	validation_0-rmse:0.01734
# [35]	validation_0-rmse:0.01646
# [36]	validation_0-rmse:0.01571
# [37]	validation_0-rmse:0.01507
# [38]	validation_0-rmse:0.01454
# [39]	validation_0-rmse:0.01409
# [40]	validation_0-rmse:0.01371
# [41]	validation_0-rmse:0.01340
# [42]	validation_0-rmse:0.01315
# [43]	validation_0-rmse:0.01294
# [44]	validation_0-rmse:0.01276
# [45]	validation_0-rmse:0.01262
# [46]	validation_0-rmse:0.01250
# [47]	validation_0-rmse:0.01241
# [48]	validation_0-rmse:0.01233
# [49]	validation_0-rmse:0.01226
# [50]	validation_0-rmse:0.01221
# [51]	validation_0-rmse:0.01217
# [52]	validation_0-rmse:0.01214
# [53]	validation_0-rmse:0.01211
# [54]	validation_0-rmse:0.01209
# [55]	validation_0-rmse:0.01207
# [56]	validation_0-rmse:0.01205
# [57]	validation_0-rmse:0.01204
# [58]	validation_0-rmse:0.01203
# [59]	validation_0-rmse:0.01202
# [60]	validation_0-rmse:0.01202
# [61]	validation_0-rmse:0.01201
# [62]	validation_0-rmse:0.01201
# [63]	validation_0-rmse:0.01200
# [64]	validation_0-rmse:0.01200
# [65]	validation_0-rmse:0.01200
# [66]	validation_0-rmse:0.01200
# [67]	validation_0-rmse:0.01200
# [68]	validation_0-rmse:0.01200
# [69]	validation_0-rmse:0.01199
# [70]	validation_0-rmse:0.01199
# [71]	validation_0-rmse:0.01199
# [72]	validation_0-rmse:0.01199
# [73]	validation_0-rmse:0.01199
# [74]	validation_0-rmse:0.01199
# [75]	validation_0-rmse:0.01199
# [76]	validation_0-rmse:0.01199
# [77]	validation_0-rmse:0.01199
# [78]	validation_0-rmse:0.01199
# [79]	validation_0-rmse:0.01199
# [80]	validation_0-rmse:0.01199
#     fold=0, train score=0.0013661, cv score=0.0001668
#
# [0]	validation_0-rmse:0.45017
# [1]	validation_0-rmse:0.40519
# [2]	validation_0-rmse:0.36471
# [3]	validation_0-rmse:0.32829
# [4]	validation_0-rmse:0.29551
# [5]	validation_0-rmse:0.26601
# [6]	validation_0-rmse:0.23947
# [7]	validation_0-rmse:0.21558
# [8]	validation_0-rmse:0.19410
# [9]	validation_0-rmse:0.17477
# [10]	validation_0-rmse:0.15738
# [11]	validation_0-rmse:0.14174
# [12]	validation_0-rmse:0.12768
# [13]	validation_0-rmse:0.11503
# [14]	validation_0-rmse:0.10366
# [15]	validation_0-rmse:0.09345
# [16]	validation_0-rmse:0.08427
# [17]	validation_0-rmse:0.07602
# [18]	validation_0-rmse:0.06862
# [19]	validation_0-rmse:0.06199
# [20]	validation_0-rmse:0.05603
# [21]	validation_0-rmse:0.05070
# [22]	validation_0-rmse:0.04593
# [23]	validation_0-rmse:0.04167
# [24]	validation_0-rmse:0.03787
# [25]	validation_0-rmse:0.03449
# [26]	validation_0-rmse:0.03148
# [27]	validation_0-rmse:0.02881
# [28]	validation_0-rmse:0.02645
# [29]	validation_0-rmse:0.02438
# [30]	validation_0-rmse:0.02255
# [31]	validation_0-rmse:0.02097
# [32]	validation_0-rmse:0.01958
# [33]	validation_0-rmse:0.01838
# [34]	validation_0-rmse:0.01735
# [35]	validation_0-rmse:0.01647
# [36]	validation_0-rmse:0.01572
# [37]	validation_0-rmse:0.01509
# [38]	validation_0-rmse:0.01455
# [39]	validation_0-rmse:0.01410
# [40]	validation_0-rmse:0.01373
# [41]	validation_0-rmse:0.01342
# [42]	validation_0-rmse:0.01316
# [43]	validation_0-rmse:0.01295
# [44]	validation_0-rmse:0.01278
# [45]	validation_0-rmse:0.01263
# [46]	validation_0-rmse:0.01252
# [47]	validation_0-rmse:0.01242
# [48]	validation_0-rmse:0.01234
# [49]	validation_0-rmse:0.01228
# [50]	validation_0-rmse:0.01223
# [51]	validation_0-rmse:0.01218
# [52]	validation_0-rmse:0.01215
# [53]	validation_0-rmse:0.01212
# [54]	validation_0-rmse:0.01210
# [55]	validation_0-rmse:0.01208
# [56]	validation_0-rmse:0.01207
# [57]	validation_0-rmse:0.01205
# [58]	validation_0-rmse:0.01204
# [59]	validation_0-rmse:0.01204
# [60]	validation_0-rmse:0.01203
# [61]	validation_0-rmse:0.01202
# [62]	validation_0-rmse:0.01202
# [63]	validation_0-rmse:0.01202
# [64]	validation_0-rmse:0.01201
# [65]	validation_0-rmse:0.01201
# [66]	validation_0-rmse:0.01201
# [67]	validation_0-rmse:0.01201
# [68]	validation_0-rmse:0.01201
# [69]	validation_0-rmse:0.01201
# [70]	validation_0-rmse:0.01200
# [71]	validation_0-rmse:0.01200
# [72]	validation_0-rmse:0.01200
# [73]	validation_0-rmse:0.01200
# [74]	validation_0-rmse:0.01200
# [75]	validation_0-rmse:0.01200
# [76]	validation_0-rmse:0.01200
# [77]	validation_0-rmse:0.01200
# [78]	validation_0-rmse:0.01200
# [79]	validation_0-rmse:0.01200
# [80]	validation_0-rmse:0.01200
# [81]	validation_0-rmse:0.01200
#     fold=1, train score=0.0015864, cv score=0.0000974
#
# [0]	validation_0-rmse:0.45014
# [1]	validation_0-rmse:0.40515
# [2]	validation_0-rmse:0.36467
# [3]	validation_0-rmse:0.32825
# [4]	validation_0-rmse:0.29547
# [5]	validation_0-rmse:0.26597
# [6]	validation_0-rmse:0.23942
# [7]	validation_0-rmse:0.21554
# [8]	validation_0-rmse:0.19405
# [9]	validation_0-rmse:0.17472
# [10]	validation_0-rmse:0.15734
# [11]	validation_0-rmse:0.14170
# [12]	validation_0-rmse:0.12763
# [13]	validation_0-rmse:0.11498
# [14]	validation_0-rmse:0.10361
# [15]	validation_0-rmse:0.09339
# [16]	validation_0-rmse:0.08421
# [17]	validation_0-rmse:0.07597
# [18]	validation_0-rmse:0.06856
# [19]	validation_0-rmse:0.06192
# [20]	validation_0-rmse:0.05596
# [21]	validation_0-rmse:0.05063
# [22]	validation_0-rmse:0.04586
# [23]	validation_0-rmse:0.04159
# [24]	validation_0-rmse:0.03779
# [25]	validation_0-rmse:0.03440
# [26]	validation_0-rmse:0.03139
# [27]	validation_0-rmse:0.02871
# [28]	validation_0-rmse:0.02635
# [29]	validation_0-rmse:0.02428
# [30]	validation_0-rmse:0.02245
# [31]	validation_0-rmse:0.02085
# [32]	validation_0-rmse:0.01947
# [33]	validation_0-rmse:0.01827
# [34]	validation_0-rmse:0.01723
# [35]	validation_0-rmse:0.01634
# [36]	validation_0-rmse:0.01559
# [37]	validation_0-rmse:0.01495
# [38]	validation_0-rmse:0.01442
# [39]	validation_0-rmse:0.01396
# [40]	validation_0-rmse:0.01359
# [41]	validation_0-rmse:0.01328
# [42]	validation_0-rmse:0.01302
# [43]	validation_0-rmse:0.01281
# [44]	validation_0-rmse:0.01263
# [45]	validation_0-rmse:0.01249
# [46]	validation_0-rmse:0.01237
# [47]	validation_0-rmse:0.01227
# [48]	validation_0-rmse:0.01220
# [49]	validation_0-rmse:0.01213
# [50]	validation_0-rmse:0.01208
# [51]	validation_0-rmse:0.01204
# [52]	validation_0-rmse:0.01200
# [53]	validation_0-rmse:0.01198
# [54]	validation_0-rmse:0.01195
# [55]	validation_0-rmse:0.01193
# [56]	validation_0-rmse:0.01192
# [57]	validation_0-rmse:0.01191
# [58]	validation_0-rmse:0.01190
# [59]	validation_0-rmse:0.01189
# [60]	validation_0-rmse:0.01188
# [61]	validation_0-rmse:0.01188
# [62]	validation_0-rmse:0.01188
# [63]	validation_0-rmse:0.01187
# [64]	validation_0-rmse:0.01187
# [65]	validation_0-rmse:0.01187
# [66]	validation_0-rmse:0.01187
# [67]	validation_0-rmse:0.01187
# [68]	validation_0-rmse:0.01186
# [69]	validation_0-rmse:0.01186
# [70]	validation_0-rmse:0.01186
# [71]	validation_0-rmse:0.01186
# [72]	validation_0-rmse:0.01186
# [73]	validation_0-rmse:0.01186
# [74]	validation_0-rmse:0.01186
# [75]	validation_0-rmse:0.01186
# [76]	validation_0-rmse:0.01186
# [77]	validation_0-rmse:0.01186
# [78]	validation_0-rmse:0.01186
# [79]	validation_0-rmse:0.01186
# [80]	validation_0-rmse:0.01186
# [81]	validation_0-rmse:0.01186
#     fold=2, train score=0.0014993, cv score=-0.0001181
#
# [0]	validation_0-rmse:0.45016
# [1]	validation_0-rmse:0.40518
# [2]	validation_0-rmse:0.36471
# [3]	validation_0-rmse:0.32828
# [4]	validation_0-rmse:0.29550
# [5]	validation_0-rmse:0.26601
# [6]	validation_0-rmse:0.23947
# [7]	validation_0-rmse:0.21559
# [8]	validation_0-rmse:0.19411
# [9]	validation_0-rmse:0.17478
# [10]	validation_0-rmse:0.15739
# [11]	validation_0-rmse:0.14176
# [12]	validation_0-rmse:0.12770
# [13]	validation_0-rmse:0.11506
# [14]	validation_0-rmse:0.10369
# [15]	validation_0-rmse:0.09348
# [16]	validation_0-rmse:0.08430
# [17]	validation_0-rmse:0.07606
# [18]	validation_0-rmse:0.06867
# [19]	validation_0-rmse:0.06204
# [20]	validation_0-rmse:0.05609
# [21]	validation_0-rmse:0.05077
# [22]	validation_0-rmse:0.04601
# [23]	validation_0-rmse:0.04176
# [24]	validation_0-rmse:0.03796
# [25]	validation_0-rmse:0.03459
# [26]	validation_0-rmse:0.03159
# [27]	validation_0-rmse:0.02894
# [28]	validation_0-rmse:0.02659
# [29]	validation_0-rmse:0.02453
# [30]	validation_0-rmse:0.02272
# [31]	validation_0-rmse:0.02115
# [32]	validation_0-rmse:0.01978
# [33]	validation_0-rmse:0.01859
# [34]	validation_0-rmse:0.01758
# [35]	validation_0-rmse:0.01671
# [36]	validation_0-rmse:0.01597
# [37]	validation_0-rmse:0.01534
# [38]	validation_0-rmse:0.01482
# [39]	validation_0-rmse:0.01438
# [40]	validation_0-rmse:0.01401
# [41]	validation_0-rmse:0.01371
# [42]	validation_0-rmse:0.01345
# [43]	validation_0-rmse:0.01325
# [44]	validation_0-rmse:0.01308
# [45]	validation_0-rmse:0.01294
# [46]	validation_0-rmse:0.01282
# [47]	validation_0-rmse:0.01273
# [48]	validation_0-rmse:0.01265
# [49]	validation_0-rmse:0.01259
# [50]	validation_0-rmse:0.01254
# [51]	validation_0-rmse:0.01250
# [52]	validation_0-rmse:0.01247
# [53]	validation_0-rmse:0.01244
# [54]	validation_0-rmse:0.01242
# [55]	validation_0-rmse:0.01240
# [56]	validation_0-rmse:0.01239
# [57]	validation_0-rmse:0.01238
# [58]	validation_0-rmse:0.01237
# [59]	validation_0-rmse:0.01236
# [60]	validation_0-rmse:0.01235
# [61]	validation_0-rmse:0.01235
# [62]	validation_0-rmse:0.01234
# [63]	validation_0-rmse:0.01234
# [64]	validation_0-rmse:0.01234
# [65]	validation_0-rmse:0.01234
# [66]	validation_0-rmse:0.01233
# [67]	validation_0-rmse:0.01233
# [68]	validation_0-rmse:0.01233
# [69]	validation_0-rmse:0.01233
# [70]	validation_0-rmse:0.01233
# [71]	validation_0-rmse:0.01233
# [72]	validation_0-rmse:0.01233
# [73]	validation_0-rmse:0.01233
# [74]	validation_0-rmse:0.01233
# [75]	validation_0-rmse:0.01233
# [76]	validation_0-rmse:0.01233
# [77]	validation_0-rmse:0.01233
# [78]	validation_0-rmse:0.01233
# [79]	validation_0-rmse:0.01233
# [80]	validation_0-rmse:0.01233
# [81]	validation_0-rmse:0.01233
# [82]	validation_0-rmse:0.01233
#     fold=3, train score=0.0014540, cv score=0.0000612
#
# [0]	validation_0-rmse:0.45016
# [1]	validation_0-rmse:0.40518
# [2]	validation_0-rmse:0.36470
# [3]	validation_0-rmse:0.32828
# [4]	validation_0-rmse:0.29550
# [5]	validation_0-rmse:0.26600
# [6]	validation_0-rmse:0.23946
# [7]	validation_0-rmse:0.21558
# [8]	validation_0-rmse:0.19409
# [9]	validation_0-rmse:0.17477
# [10]	validation_0-rmse:0.15738
# [11]	validation_0-rmse:0.14174
# [12]	validation_0-rmse:0.12768
# [13]	validation_0-rmse:0.11504
# [14]	validation_0-rmse:0.10367
# [15]	validation_0-rmse:0.09345
# [16]	validation_0-rmse:0.08428
# [17]	validation_0-rmse:0.07603
# [18]	validation_0-rmse:0.06864
# [19]	validation_0-rmse:0.06200
# [20]	validation_0-rmse:0.05605
# [21]	validation_0-rmse:0.05073
# [22]	validation_0-rmse:0.04596
# [23]	validation_0-rmse:0.04170
# [24]	validation_0-rmse:0.03791
# [25]	validation_0-rmse:0.03452
# [26]	validation_0-rmse:0.03152
# [27]	validation_0-rmse:0.02886
# [28]	validation_0-rmse:0.02651
# [29]	validation_0-rmse:0.02444
# [30]	validation_0-rmse:0.02263
# [31]	validation_0-rmse:0.02105
# [32]	validation_0-rmse:0.01967
# [33]	validation_0-rmse:0.01848
# [34]	validation_0-rmse:0.01746
# [35]	validation_0-rmse:0.01658
# [36]	validation_0-rmse:0.01584
# [37]	validation_0-rmse:0.01521
# [38]	validation_0-rmse:0.01468
# [39]	validation_0-rmse:0.01423
# [40]	validation_0-rmse:0.01386
# [41]	validation_0-rmse:0.01355
# [42]	validation_0-rmse:0.01330
# [43]	validation_0-rmse:0.01309
# [44]	validation_0-rmse:0.01292
# [45]	validation_0-rmse:0.01278
# [46]	validation_0-rmse:0.01266
# [47]	validation_0-rmse:0.01257
# [48]	validation_0-rmse:0.01249
# [49]	validation_0-rmse:0.01243
# [50]	validation_0-rmse:0.01238
# [51]	validation_0-rmse:0.01234
# [52]	validation_0-rmse:0.01230
# [53]	validation_0-rmse:0.01228
# [54]	validation_0-rmse:0.01225
# [55]	validation_0-rmse:0.01224
# [56]	validation_0-rmse:0.01222
# [57]	validation_0-rmse:0.01221
# [58]	validation_0-rmse:0.01220
# [59]	validation_0-rmse:0.01219
# [60]	validation_0-rmse:0.01218
# [61]	validation_0-rmse:0.01218
# [62]	validation_0-rmse:0.01218
# [63]	validation_0-rmse:0.01217
# [64]	validation_0-rmse:0.01217
# [65]	validation_0-rmse:0.01217
# [66]	validation_0-rmse:0.01217
# [67]	validation_0-rmse:0.01216
# [68]	validation_0-rmse:0.01216
# [69]	validation_0-rmse:0.01216
# [70]	validation_0-rmse:0.01216
# [71]	validation_0-rmse:0.01216
# [72]	validation_0-rmse:0.01216
# [73]	validation_0-rmse:0.01216
# [74]	validation_0-rmse:0.01216
# [75]	validation_0-rmse:0.01216
# [76]	validation_0-rmse:0.01216
# [77]	validation_0-rmse:0.01216
# [78]	validation_0-rmse:0.01216
# [79]	validation_0-rmse:0.01216
# [80]	validation_0-rmse:0.01216
# [81]	validation_0-rmse:0.01216
# [82]	validation_0-rmse:0.01216
#     fold=4, train score=0.0011616, cv score=0.0003540
#
# cross-validation completed, refitting on the whole train set
# best parameter:
# {'xgb__subsample': 0.5, 'xgb__reg_alpha': 1, 'xgb__n_estimators': 300, 'xgb__max_depth': 3, 'xgb__learning_rate': 0.1, 'xgb__colsample_bytree': 0.5}
# [0]	validation_0-rmse:0.45016
# [1]	validation_0-rmse:0.40518
# [2]	validation_0-rmse:0.36469
# [3]	validation_0-rmse:0.32827
# [4]	validation_0-rmse:0.29549
# [5]	validation_0-rmse:0.26599
# [6]	validation_0-rmse:0.23945
# [7]	validation_0-rmse:0.21557
# [8]	validation_0-rmse:0.19409
# [9]	validation_0-rmse:0.17476
# [10]	validation_0-rmse:0.15737
# [11]	validation_0-rmse:0.14173
# [12]	validation_0-rmse:0.12767
# [13]	validation_0-rmse:0.11502
# [14]	validation_0-rmse:0.10365
# [15]	validation_0-rmse:0.09344
# [16]	validation_0-rmse:0.08426
# [17]	validation_0-rmse:0.07602
# [18]	validation_0-rmse:0.06862
# [19]	validation_0-rmse:0.06198
# [20]	validation_0-rmse:0.05603
# [21]	validation_0-rmse:0.05070
# [22]	validation_0-rmse:0.04594
# [23]	validation_0-rmse:0.04168
# [24]	validation_0-rmse:0.03788
# [25]	validation_0-rmse:0.03449
# [26]	validation_0-rmse:0.03149
# [27]	validation_0-rmse:0.02882
# [28]	validation_0-rmse:0.02647
# [29]	validation_0-rmse:0.02440
# [30]	validation_0-rmse:0.02258
# [31]	validation_0-rmse:0.02099
# [32]	validation_0-rmse:0.01961
# [33]	validation_0-rmse:0.01842
# [34]	validation_0-rmse:0.01739
# [35]	validation_0-rmse:0.01651
# [36]	validation_0-rmse:0.01577
# [37]	validation_0-rmse:0.01513
# [38]	validation_0-rmse:0.01460
# [39]	validation_0-rmse:0.01415
# [40]	validation_0-rmse:0.01378
# [41]	validation_0-rmse:0.01347
# [42]	validation_0-rmse:0.01322
# [43]	validation_0-rmse:0.01301
# [44]	validation_0-rmse:0.01283
# [45]	validation_0-rmse:0.01269
# [46]	validation_0-rmse:0.01257
# [47]	validation_0-rmse:0.01248
# [48]	validation_0-rmse:0.01240
# [49]	validation_0-rmse:0.01234
# [50]	validation_0-rmse:0.01229
# [51]	validation_0-rmse:0.01225
# [52]	validation_0-rmse:0.01221
# [53]	validation_0-rmse:0.01218
# [54]	validation_0-rmse:0.01216
# [55]	validation_0-rmse:0.01214
# [56]	validation_0-rmse:0.01213
# [57]	validation_0-rmse:0.01212
# [58]	validation_0-rmse:0.01210
# [59]	validation_0-rmse:0.01210
# [60]	validation_0-rmse:0.01209
# [61]	validation_0-rmse:0.01209
# [62]	validation_0-rmse:0.01208
# [63]	validation_0-rmse:0.01208
# [64]	validation_0-rmse:0.01207
# [65]	validation_0-rmse:0.01207
# [66]	validation_0-rmse:0.01207
# [67]	validation_0-rmse:0.01207
# [68]	validation_0-rmse:0.01207
# [69]	validation_0-rmse:0.01206
# [70]	validation_0-rmse:0.01206
# [71]	validation_0-rmse:0.01206
# [72]	validation_0-rmse:0.01206
# [73]	validation_0-rmse:0.01206
# [74]	validation_0-rmse:0.01206
# [75]	validation_0-rmse:0.01206
# [76]	validation_0-rmse:0.01206
# [77]	validation_0-rmse:0.01206
# [78]	validation_0-rmse:0.01206
# [79]	validation_0-rmse:0.01206
# [80]	validation_0-rmse:0.01206
# [81]	validation_0-rmse:0.01206
# [82]	validation_0-rmse:0.01206
# [83]	validation_0-rmse:0.01206
# [84]	validation_0-rmse:0.01206
# [85]	validation_0-rmse:0.01206
# [86]	validation_0-rmse:0.01206
# [87]	validation_0-rmse:0.01206
# [88]	validation_0-rmse:0.01206
# [89]	validation_0-rmse:0.01206
# [90]	validation_0-rmse:0.01206
# [91]	validation_0-rmse:0.01206
# [92]	validation_0-rmse:0.01206
# weighted R^2 in train set:  0.00011225878964498115
# Wall time: 2min 55s

# %%
print(search_xgb.best_params_)
print('weighted R^2 in train set: ', search_xgb.best_estimator.score(X_train, y_train, sample_weight=w_train))
print('weighted R^2 in test set: ', search_xgb.best_estimator.score(X_test, y_test, sample_weight=w_test))
# Out:
# {'xgb__subsample': 0.5, 'xgb__reg_alpha': 1, 'xgb__n_estimators': 300, 'xgb__max_depth': 3, 'xgb__learning_rate': 0.1, 'xgb__colsample_bytree': 0.5}
# weighted R^2 in train set:  0.0016761314401378957
# weighted R^2 in test set:  0.0005654943239634669

# %% [markdown]
# ## XGBoost, with GridSearchWeightedCV

# %%
# # load model
# with open('models/xgboost, 19 features.pickle', 'rb') as f:
#     tt_xgb = dill_pickle.load(f)

# print('weighted R^2 in train set: ', tt_xgb.score(X_train, y_train, sample_weight=w_train))
# print('weighted R^2 in test set: ', tt_xgb.score(X_test, y_test, sample_weight=w_test))
# Out:
# weighted R^2 in train set:  0.00120500092863296
# weighted R^2 in test set:  0.0003740739962669881

# %%
# # predict
# y_pred_train_xgb = pd.DataFrame(tt_xgb.predict(X_train), index=y_train.index, columns=['y_pred'])
# y_pred_test_xgb = pd.DataFrame(tt_xgb.predict(X_test), index=y_test.index, columns=['y_pred'])
# y_pred_xgb = pd.concat([y_pred_train_xgb, y_pred_test_xgb])
# y_pred_xgb.to_pickle('models/y_pred_xgb, 19 features.pickle')
